# %% [markdown]
# <a href="https://colab.research.google.com/github/TheClassicTechno/cleansea_model/blob/main/surreal_version/small_taco_try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import pandas as pd
import numpy as np
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import pathlib
import cv2
import glob

# %%
#processing images
bottles1 = '/content/drive/MyDrive/TEAM9SURESTART/taco/bottles'
cans1 = '/content/drive/MyDrive/TEAM9SURESTART/taco/cans'
containers1 = '/content/drive/MyDrive/TEAM9SURESTART/taco/containers'
#paper1 = '/content/drive/MyDrive/TEAM9SURESTART/taco/paper'
#plastic1 = '/content/drive/MyDrive/TEAM9SURESTART/taco/plastic'

bottles = [cv2.imread(image) for image in glob.glob(bottles1)]
cans = [cv2.imread(image) for image in glob.glob(cans1)]
containers = [cv2.imread(image) for image in glob.glob(containers1)]
#paper = [cv2.imread(image) for image in glob.glob(paper1)]
#plastic = [cv2.imread(image) for image in glob.glob(plastic1)]

train_dataset = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/TEAM9SURESTART/taco',
    validation_split = 0.1,
    subset = "training",
    seed = 24,  
    image_size = (256, 256),
    batch_size = 8
)

val_dataset = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/TEAM9SURESTART/taco',
    validation_split = 0.1,
    subset = "validation",
    seed = 24,  
    image_size = (256, 256),
    batch_size = 8
)
from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(train_dataset, val_dataset, test_size = 0.1, random_state = 1, stratify = val_dataset)

from scipy.stats import zscore
import pandas as pd

# Create a sample df

# Calculate the zscores and drop zscores into new column

train_dataset = train_dataset.cache().shuffle(13).prefetch(buffer_size = tf.data.AUTOTUNE)
val_dataset = val_dataset.cache().shuffle(13).prefetch(buffer_size = tf.data.AUTOTUNE)
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.9),
])
model = Sequential ([
    #try add augmentations here
    #layers.RandomFlip("horizontal_and_vertical"),
    #layers.RandomRotation(0.2),
    
    layers.Rescaling(1./255, input_shape = (256, 256, 3)),
    #data_augmentation,
    layers.Conv2D(16, 3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),
    layers.Conv2D(32, 3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),
    layers.Conv2D(16, 3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),
    layers.Flatten(),
    layers.Dense(32, activation = 'relu'),
    layers.Dense(4, activation = 'softmax')
])
model.summary()
# Out:
# Found 230 files belonging to 4 classes.
# Using 207 files for training.
# Found 230 files belonging to 4 classes.
# Using 23 files for validation.
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_5 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_15 (Conv2D)          (None, 256, 256, 16)      448
#
#  max_pooling2d_15 (MaxPoolin  (None, 128, 128, 16)     0
#  g2D)
#
#  dropout_15 (Dropout)        (None, 128, 128, 16)      0
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 32)      4640
#
#  max_pooling2d_16 (MaxPoolin  (None, 64, 64, 32)       0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 64, 64, 32)        0
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 16)        4624
#
#  max_pooling2d_17 (MaxPoolin  (None, 32, 32, 16)       0
#  g2D)
#
#  dropout_17 (Dropout)        (None, 32, 32, 16)        0
#
#  flatten_5 (Flatten)         (None, 16384)             0
#
#  dense_10 (Dense)            (None, 32)                524320
#
#  dense_11 (Dense)            (None, 4)                 132
#
# =================================================================
# Total params: 534,164
# Trainable params: 534,164
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True), metrics = ['accuracy'])
'''
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=['accuracy'],  run_eagerly=True
)
'''

model.fit (
    train_dataset, 
    validation_data = val_dataset,
    epochs = 150
)
model.save('model.h5')
# Out:
# Epoch 1/150
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 26/26 [==============================] - 1s 18ms/step - loss: 1.5105 - accuracy: 0.4203 - val_loss: 1.3581 - val_accuracy: 0.5652
# Epoch 2/150
# 26/26 [==============================] - 0s 8ms/step - loss: 1.2818 - accuracy: 0.4493 - val_loss: 1.2986 - val_accuracy: 0.5652
# Epoch 3/150
# 26/26 [==============================] - 0s 8ms/step - loss: 1.2510 - accuracy: 0.4493 - val_loss: 1.3523 - val_accuracy: 0.5652
# Epoch 4/150
# 26/26 [==============================] - 0s 8ms/step - loss: 1.2700 - accuracy: 0.4541 - val_loss: 1.2991 - val_accuracy: 0.5652
# Epoch 5/150
# 26/26 [==============================] - 0s 8ms/step - loss: 1.1850 - accuracy: 0.4734 - val_loss: 1.2443 - val_accuracy: 0.5652
# Epoch 6/150
# 26/26 [==============================] - 0s 8ms/step - loss: 1.2079 - accuracy: 0.4879 - val_loss: 1.2110 - val_accuracy: 0.5652
# Epoch 7/150
# 26/26 [==============================] - 0s 8ms/step - loss: 1.1150 - accuracy: 0.5314 - val_loss: 1.1930 - val_accuracy: 0.5652
# Epoch 8/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.9732 - accuracy: 0.5894 - val_loss: 1.1046 - val_accuracy: 0.6522
# Epoch 9/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.8205 - accuracy: 0.6522 - val_loss: 0.9931 - val_accuracy: 0.6957
# Epoch 10/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.6614 - accuracy: 0.7585 - val_loss: 0.8363 - val_accuracy: 0.6957
# Epoch 11/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.5976 - accuracy: 0.7923 - val_loss: 0.8358 - val_accuracy: 0.6957
# Epoch 12/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.6262 - accuracy: 0.7536 - val_loss: 0.7954 - val_accuracy: 0.7391
# Epoch 13/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.4232 - accuracy: 0.8406 - val_loss: 0.6049 - val_accuracy: 0.7826
# Epoch 14/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.3680 - accuracy: 0.8551 - val_loss: 0.5480 - val_accuracy: 0.8261
# Epoch 15/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.3330 - accuracy: 0.8502 - val_loss: 0.5804 - val_accuracy: 0.9565
# Epoch 16/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.2655 - accuracy: 0.8937 - val_loss: 0.4257 - val_accuracy: 0.8261
# Epoch 17/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.2267 - accuracy: 0.8986 - val_loss: 0.3684 - val_accuracy: 0.8696
# Epoch 18/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.2035 - accuracy: 0.8841 - val_loss: 0.3095 - val_accuracy: 0.8261
# Epoch 19/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.2819 - accuracy: 0.9179 - val_loss: 0.6025 - val_accuracy: 0.8696
# Epoch 20/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.2982 - accuracy: 0.9275 - val_loss: 0.4476 - val_accuracy: 0.8261
# Epoch 21/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1631 - accuracy: 0.9565 - val_loss: 0.3453 - val_accuracy: 0.8696
# Epoch 22/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1205 - accuracy: 0.9710 - val_loss: 0.6078 - val_accuracy: 0.8261
# Epoch 23/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1113 - accuracy: 0.9758 - val_loss: 0.2046 - val_accuracy: 0.9130
# Epoch 24/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0649 - accuracy: 0.9758 - val_loss: 0.3236 - val_accuracy: 0.9130
# Epoch 25/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1532 - accuracy: 0.9565 - val_loss: 0.6407 - val_accuracy: 0.9130
# Epoch 26/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0513 - accuracy: 0.9952 - val_loss: 0.4556 - val_accuracy: 0.9130
# Epoch 27/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0385 - accuracy: 0.9855 - val_loss: 0.5316 - val_accuracy: 0.9130
# Epoch 28/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0672 - accuracy: 0.9903 - val_loss: 0.2733 - val_accuracy: 0.9130
# Epoch 29/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0298 - accuracy: 0.9952 - val_loss: 0.6290 - val_accuracy: 0.9130
# Epoch 30/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.3453 - val_accuracy: 0.9130
# Epoch 31/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2738 - val_accuracy: 0.9130
# Epoch 32/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.5794 - val_accuracy: 0.9130
# Epoch 33/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.5956 - val_accuracy: 0.9130
# Epoch 34/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.5835 - val_accuracy: 0.9130
# Epoch 35/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6391 - val_accuracy: 0.9130
# Epoch 36/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.7180 - val_accuracy: 0.9130
# Epoch 37/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7786 - val_accuracy: 0.9130
# Epoch 38/150
# 26/26 [==============================] - 0s 8ms/step - loss: 8.9624e-04 - accuracy: 1.0000 - val_loss: 0.6712 - val_accuracy: 0.9130
# Epoch 39/150
# 26/26 [==============================] - 0s 8ms/step - loss: 9.8348e-04 - accuracy: 1.0000 - val_loss: 0.6711 - val_accuracy: 0.9130
# Epoch 40/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.7110 - val_accuracy: 0.9130
# Epoch 41/150
# 26/26 [==============================] - 0s 8ms/step - loss: 6.5898e-04 - accuracy: 1.0000 - val_loss: 0.8234 - val_accuracy: 0.9130
# Epoch 42/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.8683 - val_accuracy: 0.9130
# Epoch 43/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.9093 - val_accuracy: 0.9130
# Epoch 44/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.8634 - val_accuracy: 0.9130
# Epoch 45/150
# 26/26 [==============================] - 0s 8ms/step - loss: 5.2378e-04 - accuracy: 1.0000 - val_loss: 0.8613 - val_accuracy: 0.9130
# Epoch 46/150
# 26/26 [==============================] - 0s 8ms/step - loss: 6.2856e-04 - accuracy: 1.0000 - val_loss: 0.9187 - val_accuracy: 0.9130
# Epoch 47/150
# 26/26 [==============================] - 0s 8ms/step - loss: 4.7544e-04 - accuracy: 1.0000 - val_loss: 1.0378 - val_accuracy: 0.9130
# Epoch 48/150
# 26/26 [==============================] - 0s 8ms/step - loss: 4.2024e-04 - accuracy: 1.0000 - val_loss: 1.0329 - val_accuracy: 0.9130
# Epoch 49/150
# 26/26 [==============================] - 0s 8ms/step - loss: 6.9327e-04 - accuracy: 1.0000 - val_loss: 1.0091 - val_accuracy: 0.9130
# Epoch 50/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.3549 - val_accuracy: 0.9130
# Epoch 51/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.7315 - val_accuracy: 0.9130
# Epoch 52/150
# 26/26 [==============================] - 0s 8ms/step - loss: 5.4513e-04 - accuracy: 1.0000 - val_loss: 0.5126 - val_accuracy: 0.9130
# Epoch 53/150
# 26/26 [==============================] - 0s 8ms/step - loss: 2.6695e-04 - accuracy: 1.0000 - val_loss: 0.5546 - val_accuracy: 0.9130
# Epoch 54/150
# 26/26 [==============================] - 0s 8ms/step - loss: 3.6370e-04 - accuracy: 1.0000 - val_loss: 0.5949 - val_accuracy: 0.9130
# Epoch 55/150
# 26/26 [==============================] - 0s 8ms/step - loss: 3.3270e-04 - accuracy: 1.0000 - val_loss: 0.7064 - val_accuracy: 0.9130
# Epoch 56/150
# 26/26 [==============================] - 0s 8ms/step - loss: 3.0535e-04 - accuracy: 1.0000 - val_loss: 0.7700 - val_accuracy: 0.9130
# Epoch 57/150
# 26/26 [==============================] - 0s 8ms/step - loss: 3.7273e-04 - accuracy: 1.0000 - val_loss: 0.8409 - val_accuracy: 0.9130
# Epoch 58/150
# 26/26 [==============================] - 0s 8ms/step - loss: 2.4782e-04 - accuracy: 1.0000 - val_loss: 0.7955 - val_accuracy: 0.9130
# Epoch 59/150
# 26/26 [==============================] - 0s 8ms/step - loss: 2.5773e-04 - accuracy: 1.0000 - val_loss: 0.7977 - val_accuracy: 0.9130
# Epoch 60/150
# 26/26 [==============================] - 0s 8ms/step - loss: 1.9386e-04 - accuracy: 1.0000 - val_loss: 0.7803 - val_accuracy: 0.9130
# Epoch 61/150
# 26/26 [==============================] - 0s 8ms/step - loss: 2.2314e-04 - accuracy: 1.0000 - val_loss: 0.7699 - val_accuracy: 0.9130
# Epoch 62/150
# 26/26 [==============================] - 0s 8ms/step - loss: 2.8822e-04 - accuracy: 1.0000 - val_loss: 0.7660 - val_accuracy: 0.9130
# Epoch 63/150
# 26/26 [==============================] - 0s 8ms/step - loss: 2.7078e-04 - accuracy: 1.0000 - val_loss: 0.8321 - val_accuracy: 0.9130
# Epoch 64/150
# 26/26 [==============================] - 0s 8ms/step - loss: 1.6924e-04 - accuracy: 1.0000 - val_loss: 0.8413 - val_accuracy: 0.9130
# Epoch 65/150
# 26/26 [==============================] - 0s 8ms/step - loss: 3.0356e-04 - accuracy: 1.0000 - val_loss: 0.8425 - val_accuracy: 0.9130
# Epoch 66/150
# 26/26 [==============================] - 0s 8ms/step - loss: 2.3901e-04 - accuracy: 1.0000 - val_loss: 0.7431 - val_accuracy: 0.9130
# Epoch 67/150
# 26/26 [==============================] - 0s 8ms/step - loss: 2.0145e-04 - accuracy: 1.0000 - val_loss: 0.7681 - val_accuracy: 0.9130
# Epoch 68/150
# 26/26 [==============================] - 0s 8ms/step - loss: 1.9539e-04 - accuracy: 1.0000 - val_loss: 0.7742 - val_accuracy: 0.9130
# Epoch 69/150
# 26/26 [==============================] - 0s 8ms/step - loss: 1.0179e-04 - accuracy: 1.0000 - val_loss: 0.7841 - val_accuracy: 0.9130
# Epoch 70/150
# 26/26 [==============================] - 0s 8ms/step - loss: 2.1123e-04 - accuracy: 1.0000 - val_loss: 0.9076 - val_accuracy: 0.9130
# Epoch 71/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0411 - accuracy: 0.9710 - val_loss: 0.8209 - val_accuracy: 0.8261
# Epoch 72/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1842 - accuracy: 0.9565 - val_loss: 0.9301 - val_accuracy: 0.7826
# Epoch 73/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.2506 - accuracy: 0.9420 - val_loss: 0.1898 - val_accuracy: 0.9130
# Epoch 74/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0539 - accuracy: 0.9855 - val_loss: 0.6338 - val_accuracy: 0.9130
# Epoch 75/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0456 - accuracy: 0.9952 - val_loss: 0.0972 - val_accuracy: 1.0000
# Epoch 76/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0247 - accuracy: 0.9952 - val_loss: 0.0976 - val_accuracy: 0.9565
# Epoch 77/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1376 - accuracy: 0.9807 - val_loss: 0.0786 - val_accuracy: 1.0000
# Epoch 78/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1643 - accuracy: 0.9807 - val_loss: 0.0745 - val_accuracy: 1.0000
# Epoch 79/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0420 - accuracy: 0.9903 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 80/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0169 - accuracy: 0.9903 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 81/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0216 - accuracy: 0.9952 - val_loss: 0.0872 - val_accuracy: 1.0000
# Epoch 82/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 1.0000
# Epoch 83/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0420 - accuracy: 0.9952 - val_loss: 0.0860 - val_accuracy: 1.0000
# Epoch 84/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1158 - accuracy: 0.9855 - val_loss: 0.1986 - val_accuracy: 0.9565
# Epoch 85/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1326 - accuracy: 0.9662 - val_loss: 0.0814 - val_accuracy: 0.9565
# Epoch 86/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.0676 - val_accuracy: 1.0000
# Epoch 87/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 1.0000
# Epoch 88/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 1.0000
# Epoch 89/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0158 - accuracy: 0.9952 - val_loss: 0.6696 - val_accuracy: 0.9130
# Epoch 90/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0648 - accuracy: 0.9903 - val_loss: 0.1433 - val_accuracy: 0.9565
# Epoch 91/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0264 - accuracy: 0.9952 - val_loss: 0.0396 - val_accuracy: 1.0000
# Epoch 92/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 1.0000
# Epoch 93/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0544 - val_accuracy: 1.0000
# Epoch 94/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9130
# Epoch 95/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.1916 - val_accuracy: 0.9130
# Epoch 96/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.2374 - val_accuracy: 0.9130
# Epoch 97/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.2529 - val_accuracy: 0.9130
# Epoch 98/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.2509 - val_accuracy: 0.9130
# Epoch 99/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.2844 - val_accuracy: 0.9130
# Epoch 100/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0212 - accuracy: 0.9952 - val_loss: 1.2731 - val_accuracy: 0.9130
# Epoch 101/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 1.2238 - val_accuracy: 0.9130
# Epoch 102/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.1282 - val_accuracy: 0.9130
# Epoch 103/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 1.0331 - val_accuracy: 0.9130
# Epoch 104/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.9151 - val_accuracy: 0.9130
# Epoch 105/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.6854 - val_accuracy: 0.9130
# Epoch 106/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.6960 - val_accuracy: 0.9130
# Epoch 107/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.7225 - val_accuracy: 0.9130
# Epoch 108/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.6358 - val_accuracy: 0.9130
# Epoch 109/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.6214 - val_accuracy: 0.9130
# Epoch 110/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.6240 - val_accuracy: 0.9130
# Epoch 111/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.6315 - val_accuracy: 0.9130
# Epoch 112/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.6460 - val_accuracy: 0.9130
# Epoch 113/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.6572 - val_accuracy: 0.9130
# Epoch 114/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.6681 - val_accuracy: 0.9130
# Epoch 115/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.6721 - val_accuracy: 0.9130
# Epoch 116/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.6725 - val_accuracy: 0.9130
# Epoch 117/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.6233 - val_accuracy: 0.9130
# Epoch 118/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.6244 - val_accuracy: 0.9130
# Epoch 119/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.6287 - val_accuracy: 0.9130
# Epoch 120/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.6333 - val_accuracy: 0.9130
# Epoch 121/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.6617 - val_accuracy: 0.9130
# Epoch 122/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.6713 - val_accuracy: 0.9130
# Epoch 123/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.6769 - val_accuracy: 0.9130
# Epoch 124/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.6935 - val_accuracy: 0.9130
# Epoch 125/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.6915 - val_accuracy: 0.9130
# Epoch 126/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.6930 - val_accuracy: 0.9130
# Epoch 127/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.6955 - val_accuracy: 0.9130
# Epoch 128/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0156 - accuracy: 0.9952 - val_loss: 0.1140 - val_accuracy: 0.9130
# Epoch 129/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0763 - accuracy: 0.9855 - val_loss: 0.5210 - val_accuracy: 0.8696
# Epoch 130/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0895 - accuracy: 0.9903 - val_loss: 0.1088 - val_accuracy: 1.0000
# Epoch 131/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.3343 - accuracy: 0.9614 - val_loss: 0.0571 - val_accuracy: 1.0000
# Epoch 132/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0977 - accuracy: 0.9710 - val_loss: 0.1825 - val_accuracy: 0.9565
# Epoch 133/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0427 - accuracy: 0.9855 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 134/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0242 - accuracy: 0.9952 - val_loss: 0.0416 - val_accuracy: 1.0000
# Epoch 135/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.1430 - accuracy: 0.9758 - val_loss: 0.1229 - val_accuracy: 0.9565
# Epoch 136/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0263 - accuracy: 0.9952 - val_loss: 0.0877 - val_accuracy: 0.9565
# Epoch 137/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0150 - accuracy: 0.9903 - val_loss: 0.0281 - val_accuracy: 1.0000
# Epoch 138/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 1.0000
# Epoch 139/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0127 - accuracy: 0.9952 - val_loss: 0.0468 - val_accuracy: 0.9565
# Epoch 140/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0519 - val_accuracy: 1.0000
# Epoch 141/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0166 - accuracy: 0.9952 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 142/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0071 - accuracy: 0.9952 - val_loss: 0.6116 - val_accuracy: 0.9130
# Epoch 143/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0015 - val_accuracy: 0.9130
# Epoch 144/150
# 26/26 [==============================] - 0s 8ms/step - loss: 1.1137e-04 - accuracy: 1.0000 - val_loss: 1.0667 - val_accuracy: 0.9130
# Epoch 145/150
# 26/26 [==============================] - 0s 8ms/step - loss: 2.8883e-04 - accuracy: 1.0000 - val_loss: 1.0917 - val_accuracy: 0.9130
# Epoch 146/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4619 - val_accuracy: 0.9130
# Epoch 147/150
# 26/26 [==============================] - 0s 8ms/step - loss: 9.1256e-04 - accuracy: 1.0000 - val_loss: 0.2483 - val_accuracy: 0.9130
# Epoch 148/150
# 26/26 [==============================] - 0s 8ms/step - loss: 3.4101e-04 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9130
# Epoch 149/150
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1720 - val_accuracy: 0.9130
# Epoch 150/150
# 26/26 [==============================] - 0s 8ms/step - loss: 1.4907e-04 - accuracy: 1.0000 - val_loss: 0.1079 - val_accuracy: 0.9130

# %%
loss = pd.DataFrame(model.history.history)

#plotting the loss and accuracy 
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.plot(loss["loss"], label ="Loss")
plt.plot(loss["val_loss"], label = "Validation_loss")
plt.legend()
plt.title("Training and Validation Loss")

plt.subplot(2,2,2)
plt.plot(loss['accuracy'],label = "Training Accuracy")
plt.plot(loss['val_accuracy'], label ="Validation_ Accuracy ")
plt.legend()
plt.title("Training-Validation Accuracy")
# Out:
# Text(0.5, 1.0, 'Training-Validation Accuracy')
